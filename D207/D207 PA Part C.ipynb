# %%
#import packages
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %%
#read the medical csv file
df = pd.read_csv(r'C:\Users\Saemi\OneDrive\Education\WGU\D207 Exploratory Data Analysis (Python & R)\PA\medical_clean.csv')

# %%
#get the statistical values from continuous variable VitD_levels
df['VitD_levels'].describe()
# Out:
# count    10000.000000
# mean        17.964262
# std          2.017231
# min          9.806483
# 25%         16.626439
# 50%         17.951122
# 75%         19.347963
# max         26.394449
# Name: VitD_levels, dtype: float64

# %%
plt.hist(df['VitD_levels'])
plt.show()

# %%
#get the statistical values from continuous variable Initial_days
df['Initial_days'].describe()
# Out:
# count    10000.000000
# mean        34.455299
# std         26.309341
# min          1.001981
# 25%          7.896215
# 50%         35.836244
# 75%         61.161020
# max         71.981490
# Name: Initial_days, dtype: float64

# %%
plt.hist(df['Initial_days'])
plt.show()

# %%
#get the statistical values from categorical variable HighBlood
df['HighBlood'].describe()
# Out:
# count     10000
# unique        2
# top          No
# freq       5910
# Name: HighBlood, dtype: object

# %%
plt.hist(df['HighBlood'])
plt.show()

# %%
df['HighBlood'].value_counts()
# Out:
# HighBlood
# No     5910
# Yes    4090
# Name: count, dtype: int64

# %%
#get the statistical values from categorical variable Overweight
df['Overweight'].describe()
# Out:
# count     10000
# unique        2
# top         Yes
# freq       7094
# Name: Overweight, dtype: object

# %%
plt.hist(df['Overweight'])
plt.show()

# %%
df['Overweight'].value_counts()
# Out:
# Overweight
# Yes    7094
# No     2906
# Name: count, dtype: int64
